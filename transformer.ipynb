# %%
import numpy as np

# Pandas
import pandas as pd 

# Pytorch
import torch
import torch.nn as nn
from torch import Tensor
from torchsummary import summary

# Seaborn
import seaborn as sns

# Finta
from finta import TA

# Others
import matplotlib.pyplot as plt
import time
import os
import math
import copy
import sklearn.preprocessing as pp

# %%
data= pd.read_csv('data_2025-05-09_to_2025-08-09.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   datetime_utc           2208 non-null   object
#  1   log_return             2208 non-null   float64
#  2   money_flow_volume      2208 non-null   float64
#  3   money_flow_multiplier  2208 non-null   float64
#  4   low_prev_close         2208 non-null   float64
#  5   high_prev_close        2208 non-null   float64
#  6   True_Range             2208 non-null   float64
#  7   HL_diff                2208 non-null   float64
#  8   volume                 2208 non-null   float64
#  9   parkinsons_vol_10      2208 non-null   float64
#  10  parkinsons_vol_20      2208 non-null   float64
#  11  garch_volatility       2208 non-null   float64
#  12  volume_zscore          2208 non-null   float64
#  13  parkinsons_vol_50      2208 non-null   float64
#  14  ATR                    2208 non-null   float64
#  15  open                   2208 non-null   float64
#  16  close                  2208 non-null   float64
#  17  arch_volatility        2208 non-null   float64
#  18  high                   2208 non-null   float64
#  19  low                    2208 non-null   float64
#  20  hurst_50               2208 non-null   float64
#  21  trend_up               2208 non-null   int64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 379.6+ KB

# %%
data = data.sort_values('datetime_utc', ignore_index=True)

# %%
data['datetime_utc'] = pd.to_datetime(data['datetime_utc'])
data = data.rename(columns={'datetime_utc': 'Timestamp'})

# %%
data.drop(['Timestamp'], inplace=True, axis=1)

# %%
def train_validation_test_split(data, val_percentage, test_percentage):
    """Splits the data into train, validation and test

    Args:
        data: Tensor, shape [N, E]
        val_percentage: float, validation percentage from the data [0,1]
        test_percentage: float, test percentage from the data (0,1]
    Returns:
        train: Tensor, shape [N - N * (val_percentage + test_percentage), E]
        val: Tensor, shape [N * val_percentage, E] or None if val_percentage = 0
        test: Tensor, shape [N * test_percentage, E]
    """
    data_length = len(data)
    
    val_length = int(data_length * val_percentage)
    test_length = int(data_length * test_percentage)
    train_length = data_length - val_length - test_length
    
    train = data[:train_length]
    if val_length == 0:
        val = None
    else:
        val = data[train_length:train_length+val_length]
    test = data[train_length+val_length:]

    return train, val, test

# %%
def normalize_data(train, val ,test ,scaler=pp.StandardScaler()):
    """Scale the data: train, val and test according to train

    Args:
        train: Tensor, shape [N_train, E]
        val: Tensor, shape [N_val, E] (supports val=None)
        test: Tensor, shape [N_test, E]
        scaler: function, scaling function
    Returns:
        train: Tensor, shape [N_train, E]
        val: Tensor, shape [N_val, E]
        test: Tensor, shape [N_test, E]
        fitted_scaler: function, scaler fitted to train
    """
    fitted_scaler = scaler.fit(train)
    train = torch.tensor(fitted_scaler.transform(train))
    if val is not None:
        val = torch.tensor(fitted_scaler.transform(val))

    test = torch.tensor(fitted_scaler.transform(test))

    return train, val, test, fitted_scaler

# %%
def betchify(data, batch_size):
    """Divides the data into batch_size separate sequences, 
    removing extra elements that wouldn't cleanly fit.

    Args:
        data: Tensor, shape [N, E]
        batch_size: int, batch size

    Returns:
        Tensor of shape [N // batch_size, batch_size, E]
    """
    seq_len = data.size(0) // batch_size
    data = data[:seq_len * batch_size,:]
    data = data.view(batch_size, seq_len, -1)
    data = torch.transpose(data,0,1).contiguous()
    return data.to(device)

# %%
def get_batch(data, i, bptt_src, bptt_tgt, overlap):
    """Divides data to source and target, from offset i
    
    Args:
        source: Tensor, shape [N, batch_size, E]
        i: int, offset for the source
        bptt_src: int, size of back propagation through time, sequence length of source
        bptt_tgt: int, size of back propagation through time, sequence length of target
        overlap: int, number of overlapping elements between source and target

    Returns:
        source: Tensor, shape [bptt_src, batch_size, E]
        target: Tensor, shape [bptt_tgt, batch_size, E]
    """
    src_seq_len = min(bptt_src, len(data) - i - 1)
    target_seq_len = min(bptt_tgt, len(data) - i - src_seq_len + overlap)
    source = data[i: i + src_seq_len]
    target = data[i + src_seq_len - overlap: i + src_seq_len + target_seq_len - overlap]
    return source, target

# %%
class SineActivation(nn.Module):
    def __init__(self, in_features, periodic_features, out_features, dropout):
        super(SineActivation, self).__init__()
        # weights and biases for the periodic features
        self.w0 = nn.parameter.Parameter(torch.randn(in_features, out_features - in_features - periodic_features))
        self.b0 = nn.parameter.Parameter(torch.randn(1, out_features - in_features - periodic_features))
        # weights and biases for the linear features
        self.w = nn.parameter.Parameter(torch.randn(in_features, periodic_features))
        self.b = nn.parameter.Parameter(torch.randn(1, periodic_features))
        self.activation = torch.sin
        self.dropout = nn.Dropout(dropout)
        
    def Time2Vector(self, data):
        """Add features to data: 
            1. keep the original features numbered by - in_features
            2. add more periodic features numbered by - periodic_features
            3. add more linear feature to end up with total of features numbered by - out_features
    
        Args:
            data: Tensor, shape [N, batch_size, in_features]

        Returns:
            data: Tensor, shape [N, batch_size, out_features]
        """
        v_linear = torch.matmul(self.w0.t(), data.transpose(1,2)).transpose(1,2) + self.b0
        v_sin = self.activation(torch.matmul(self.w.t(), data.transpose(1,2)).transpose(1,2) + self.b)
        data = torch.cat([v_linear, v_sin, data], 2)
        return data

    def forward(self, data):
        data = self.Time2Vector(data)
        data = self.dropout(data)
        return data

# %%
class BTC_Transformer(nn.Module):
    def __init__(self,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 in_features: int,
                 periodic_features: int,
                 out_features: int,
                 nhead: int,
                 dim_feedforward: int = 512,
                 dropout: float = 0.1,
                 activation: str = 'relu'):
        super(BTC_Transformer, self).__init__()
        
        self.sine_activation = SineActivation(in_features=in_features,
                                              periodic_features=periodic_features,
                                              out_features=out_features,
                                              dropout=dropout)
        
        self.transformer = nn.Transformer(d_model=out_features,
                                          nhead=nhead,
                                          num_encoder_layers=num_encoder_layers,
                                          num_decoder_layers=num_decoder_layers,
                                          dim_feedforward=dim_feedforward,
                                          dropout=dropout,
                                          activation=activation)
        
        self.generator = nn.Linear(out_features, in_features)
    
    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer.encoder(self.sine_activation(src), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer.decoder(self.sine_activation(tgt), memory, tgt_mask)

    def forward(self,
                src: Tensor,
                trg: Tensor,
                src_mask: Tensor=None,
                tgt_mask: Tensor=None,
                mem_mask: Tensor=None,
                src_padding_mask: Tensor=None,
                tgt_padding_mask: Tensor=None,
                memory_key_padding_mask: Tensor=None):
        
        src_emb = self.sine_activation(src)
        tgt_emb = self.sine_activation(trg)
        outs = self.transformer(src_emb, tgt_emb, src_mask, tgt_mask, mem_mask,
                                src_padding_mask, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

# %%
def evaluate(model, data, bptt_src, bptt_tgt, overlap, criterion, predicted_feature):
    """run the data through the model in eval mode and calculate the average loss in the given feature
    
    Args:
        model: nn.Module, the model you want to run the data in
        data: Tensor, shape [N, batch_size, E]
        bptt_src: int, size of back propagation through time, sequence length of source
        bptt_tgt: int, size of back propagation through time, sequence length of target
        overlap: int, number of overlapping elements between source and target
        criterion: nn.module, the loss function
        predicted_feature: int, index of the feature you want to evaluate in [0,E-1]
        

    Returns:
        mean_loss: float, average loss recieved over all data on the chosen feature
    """
    model.eval()     # Turn on the evaluation mode
    total_loss = 0.
    src_mask = torch.zeros((bptt_src,bptt_src), dtype=torch.bool).to(device) # zeros mask for the source (no mask)
    tgt_mask = model.transformer.generate_square_subsequent_mask(bptt_tgt).to(device) # look-ahead mask for the target
    with torch.no_grad():
        for i in range(0, data.size(0) - 1, bptt_src):
            source, targets = get_batch(data, i, bptt_src, bptt_tgt, overlap)
            src_batch_size = source.size(0)
            tgt_batch_size = targets.size(0)
            if tgt_batch_size != bptt_tgt or src_batch_size != bptt_src:  # only on last batch
                src_mask = src_mask[:src_batch_size, :src_batch_size]
                tgt_mask = tgt_mask[:tgt_batch_size, :tgt_batch_size]       
            output = model(source, targets, src_mask, tgt_mask)
            loss = criterion(output[:-1,:,predicted_feature], targets[1:,:,predicted_feature])
            total_loss += len(source) * loss.item()
    mean_loss = total_loss / (len(data) - 1)
    return mean_loss

# %%
# split the data
val_percentage = 0.1
test_percentage = 0.1
train_df, val_df, test_df = train_validation_test_split(data, val_percentage, test_percentage)
print(np.shape(train_df))
if val_df is not None:
    print(np.shape(val_df))
print(np.shape(test_df))
# Out:
# (1768, 21)
# (220, 21)
# (220, 21)

# %%
plot_data_process = True
plot_data_process = True

# choose the Hyper-Parameters
# data Hyper-Parameters
num_features = 21 # maximum 34
scaler_name = 'minmax' # choose from ['standard','minmax']
train_batch_size = 32
eval_batch_size = 32
epochs = 50
bptt_src = 10
bptt_tgt = 2
overlap = 1

# model Hyper-Parameters
num_encoder_layers = 4
num_decoder_layers = 4
periodic_features = 10
out_features = 60  # must be greater or equal to (num_features + periodic_features)
nhead = 15 # must divide out_features
dim_feedforward = 384
dropout = 0.0
activation = 'gelu' # choose from ['relu','gelu']

# training Hyper-Parameters
random_start_point = False
clip_param = 0.75
lr = 0.5
gamma = 0.95
step_size = 1.0

# %%
start_hour = 17
start_minute = 0

# %%
if plot_data_process:
    train_time = np.arange(np.size(train_df, 0))
    if val_df is not None:
        val_time = np.arange(np.size(train_df, 0), np.size(train_df, 0) + np.size(val_df, 0))
        test_time = np.arange(np.size(train_df, 0) + np.size(val_df, 0), np.size(train_df, 0) + np.size(val_df, 0) + np.size(test_df, 0))
    else:
        test_time = np.arange(np.size(train_df, 0), np.size(train_df, 0) + np.size(test_df, 0))
    fig = plt.figure(figsize=(16, 8))
    st = fig.suptitle("Data Separation", fontsize=20)
    ax = fig.add_subplot(1, 1 ,1)
    ax.set_xlabel("Time - Minutes From (UTC+8): 2025-05-09 {:02d}:{:02d}:00".format(start_hour, start_minute))     
    ax.set_ylabel("log Price [USD]")            
    ax.set_title("log Through Time")
    ax.plot(train_time, train_df['log_return'], label='Training data')
    if val_df is not None:
        ax.plot(val_time, val_df['log_return'], label='Validation data')
    ax.plot(test_time, test_df['log_return'], label='Test data')
    ax.grid()
    ax.legend(loc="best", fontsize=12) 
    plt.show()
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# font configuration
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 14}

plt.rc('font', **font)

# %%
# Hyper-Parameters interpretation
predicted_feature = train_df.columns.get_loc('log_return')
if scaler_name == 'standard':
    scaler = pp.StandardScaler()
if scaler_name == 'minmax':
    scaler = pp.MinMaxScaler()
in_features = num_features
criterion = nn.MSELoss()

# define the model
model = BTC_Transformer(num_encoder_layers=num_encoder_layers,
                        num_decoder_layers=num_decoder_layers,
                        in_features=in_features,
                        periodic_features=periodic_features,
                        out_features=out_features,
                        nhead=nhead,
                        dim_feedforward=dim_feedforward,
                        dropout=dropout,
                        activation=activation
                       ).to(device)

# optimization
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

# create the relevant data
train = train_df.iloc[:, :num_features]
if val_df is not None:
    val = val_df.iloc[:, :num_features]
else:
    val = val_df
test = test_df.iloc[:, :num_features]
train, val ,test ,scaler = normalize_data(train, val ,test ,scaler)
train_data = betchify(train, train_batch_size).float()
if val is not None:
    val_data = betchify(val, eval_batch_size).float()
test_data = betchify(test, eval_batch_size).float()
# Out:
# c:\Users\vishal bhanu\OneDrive\Desktop\LSTM\gmadl_env\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
# print the model
model_stats = summary(
                model = model, 
                input_data = [(bptt_src, in_features), (bptt_tgt, in_features)], 
                dtypes = [torch.float, torch.float],
                batch_dim = 1,
                col_names = ("input_size", "output_size", "num_params"),
                device = device, 
                depth = 4, 
                verbose = 0
                )
print(str(model_stats))
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# ├─SineActivation: 1-1                              [10, -1, 21]              [10, -1, 60]              --
# |    └─Dropout: 2-1                                [10, -1, 60]              [10, -1, 60]              --
# ├─SineActivation: 1-2                              [2, -1, 21]               [2, -1, 60]               (recursive)
# |    └─Dropout: 2-2                                [2, -1, 60]               [2, -1, 60]               --
# ├─Transformer: 1-3                                 [10, -1, 60]              [2, -1, 60]               --
# |    └─TransformerEncoder: 2-3                     [10, -1, 60]              [10, -1, 60]              --
# |    |    └─ModuleList: 3                          []                        []                        --
# |    |    |    └─TransformerEncoderLayer: 4-1      [10, -1, 60]              [10, -1, 60]              61,404
# |    |    |    └─TransformerEncoderLayer: 4-2      [10, -1, 60]              [10, -1, 60]              61,404
# |    |    |    └─TransformerEncoderLayer: 4-3      [10, -1, 60]              [10, -1, 60]              61,404
# |    |    |    └─TransformerEncoderLayer: 4-4      [10, -1, 60]              [10, -1, 60]              61,404
# |    |    └─LayerNorm: 3-1                         [10, -1, 60]              [10, -1, 60]              120
# |    └─TransformerDecoder: 2-4                     [2, -1, 60]               [2, -1, 60]               --
# |    |    └─ModuleList: 3                          []                        []                        --
# |    |    |    └─TransformerDecoderLayer: 4-5      [2, -1, 60]               [2, -1, 60]               76,164
# |    |    |    └─TransformerDecoderLayer: 4-6      [2, -1, 60]               [2, -1, 60]               76,164
# |    |    |    └─TransformerDecoderLayer: 4-7      [2, -1, 60]               [2, -1, 60]               76,164
# |    |    |    └─TransformerDecoderLayer: 4-8      [2, -1, 60]               [2, -1, 60]               76,164
# |    |    └─LayerNorm: 3-2                         [2, -1, 60]               [2, -1, 60]               120
# ├─Linear: 1-4                                      [2, -1, 60]               [2, -1, 21]               1,281
# =============================================================================================================================
# Total params: 551,793
# Trainable params: 551,793
# Non-trainable params: 0
# Total mult-adds (M): 2.17
# =============================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.22
# Params size (MB): 2.10
# Estimated Total Size (MB): 2.32
# =============================================================================================================================

# %%
## train the model
# prepare vars to hold best model and training statistics
best_val_loss = float('inf')
best_model = None
train_loss = []
valid_loss = []

for epoch in range(1, epochs + 1):
    # epoch initialization
    epoch_start_time = time.time()
    model.train()
    total_loss = 0.
    epoch_loss = 0.
    start_time = time.time()
    
    # start point of the data
    if random_start_point:
        start_point = np.random.randint(bptt_src)
    else:
        start_point = 0
    
    num_batches = (len(train_data) - start_point) // bptt_src
    log_interval = max(1, round(num_batches // 3 / 10) * 10)
    
    # masks for the model 
    src_mask = torch.zeros((bptt_src,bptt_src), dtype=torch.bool).to(device) # zeros mask for the source (no mask)
    tgt_mask = model.transformer.generate_square_subsequent_mask(bptt_tgt).to(device) # look-ahead mask for the target
    

    for batch, i in enumerate(range(start_point, train_data.size(0) - 1, bptt_src)):
        # forward
        source, targets = get_batch(train_data, i, bptt_src, bptt_tgt, overlap)
        src_batch_size = source.size(0)
        tgt_batch_size = targets.size(0)
        if tgt_batch_size != bptt_tgt or src_batch_size != bptt_src:  # only on last batch
            src_mask = src_mask[:src_batch_size, :src_batch_size]
            tgt_mask = tgt_mask[:tgt_batch_size, :tgt_batch_size]
        output = model(source, targets, src_mask, tgt_mask)
        loss = criterion(output[:-1,:,predicted_feature], targets[1:,:,predicted_feature])
        
        # backward
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip_param)
        
        # step
        optimizer.step()
        
        # record bacth statistics
        total_loss += loss.item()
        epoch_loss += len(source) * loss.item()

        # print statistics every log_interval
        if (batch % log_interval == 0) and batch > 0:
            lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            print(f'| epoch {epoch:3d} | {batch:5d}/{num_batches:5d} batches | '
                  f'lr {lr:02.6f} | ms/batch {ms_per_batch:5.2f} | '
                  f'loss {cur_loss:5.6f} ')
            total_loss = 0
            start_time = time.time()
    
    # record epoch statistics
    train_loss.append(epoch_loss / (len(train_data) - 1))
    
    # evaluate on validation and save best model
    if val is not None:
        val_loss = evaluate(model, val_data, bptt_src, bptt_tgt, overlap, criterion, predicted_feature)
        elapsed = time.time() - epoch_start_time
        print('-' * 77)
        print(f'| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | '
             f'valid loss {val_loss:5.6f} ')
        print('-' * 77)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            
        valid_loss.append(np.mean(val_loss))

    # scheduler step
    scheduler.step()
              
if val is None:
    best_model = copy.deepcopy(model)
# Out:
# | epoch   1 |     1/    5 batches | lr 0.500000 | ms/batch 1506.89 | loss 6.276026
# | epoch   1 |     2/    5 batches | lr 0.500000 | ms/batch 68.02 | loss 5.913172
# | epoch   1 |     3/    5 batches | lr 0.500000 | ms/batch 31.71 | loss 0.166388
# | epoch   1 |     4/    5 batches | lr 0.500000 | ms/batch 39.59 | loss 5.718073
# | epoch   1 |     5/    5 batches | lr 0.500000 | ms/batch 57.59 | loss 0.106705
# -----------------------------------------------------------------------------
# | end of epoch   1 | time:  1.72s | valid loss 4.406853
# -----------------------------------------------------------------------------
# | epoch   2 |     1/    5 batches | lr 0.475000 | ms/batch 104.47 | loss 5.036942
# | epoch   2 |     2/    5 batches | lr 0.475000 | ms/batch 57.44 | loss 1.570006
# | epoch   2 |     3/    5 batches | lr 0.475000 | ms/batch 44.31 | loss 1.823581
# | epoch   2 |     4/    5 batches | lr 0.475000 | ms/batch 42.76 | loss 1.601737
# | epoch   2 |     5/    5 batches | lr 0.475000 | ms/batch 30.99 | loss 1.451633
# -----------------------------------------------------------------------------
# | end of epoch   2 | time:  0.31s | valid loss 0.913586
# -----------------------------------------------------------------------------
# | epoch   3 |     1/    5 batches | lr 0.451250 | ms/batch 108.69 | loss 1.906953
# | epoch   3 |     2/    5 batches | lr 0.451250 | ms/batch 51.62 | loss 0.252619
# | epoch   3 |     3/    5 batches | lr 0.451250 | ms/batch 44.93 | loss 0.182186
# | epoch   3 |     4/    5 batches | lr 0.451250 | ms/batch 32.31 | loss 0.209356
# | epoch   3 |     5/    5 batches | lr 0.451250 | ms/batch 47.46 | loss 0.442123
# -----------------------------------------------------------------------------
# | end of epoch   3 | time:  0.31s | valid loss 3.850143
# -----------------------------------------------------------------------------
# | epoch   4 |     1/    5 batches | lr 0.428687 | ms/batch 108.32 | loss 4.074346
# | epoch   4 |     2/    5 batches | lr 0.428687 | ms/batch 55.53 | loss 3.766542
# | epoch   4 |     3/    5 batches | lr 0.428687 | ms/batch 47.06 | loss 0.248254
# | epoch   4 |     4/    5 batches | lr 0.428687 | ms/batch 39.99 | loss 3.794289
# | epoch   4 |     5/    5 batches | lr 0.428687 | ms/batch 31.64 | loss 0.221424
# -----------------------------------------------------------------------------
# | end of epoch   4 | time:  0.31s | valid loss 3.704595
# -----------------------------------------------------------------------------
# | epoch   5 |     1/    5 batches | lr 0.407253 | ms/batch 91.32 | loss 3.741814
# | epoch   5 |     2/    5 batches | lr 0.407253 | ms/batch 55.62 | loss 3.624876
# | epoch   5 |     3/    5 batches | lr 0.407253 | ms/batch 49.63 | loss 0.123489
# | epoch   5 |     4/    5 batches | lr 0.407253 | ms/batch 31.77 | loss 3.644403
# | epoch   5 |     5/    5 batches | lr 0.407253 | ms/batch 56.76 | loss 0.104564
# -----------------------------------------------------------------------------
# | end of epoch   5 | time:  0.31s | valid loss 3.557528
# -----------------------------------------------------------------------------
# | epoch   6 |     1/    5 batches | lr 0.386890 | ms/batch 125.03 | loss 3.477166
# | epoch   6 |     2/    5 batches | lr 0.386890 | ms/batch 46.47 | loss 3.358365
# | epoch   6 |     3/    5 batches | lr 0.386890 | ms/batch 54.19 | loss 0.061866
# | epoch   6 |     4/    5 batches | lr 0.386890 | ms/batch 38.91 | loss 3.239504
# | epoch   6 |     5/    5 batches | lr 0.386890 | ms/batch 47.79 | loss 0.051510
# -----------------------------------------------------------------------------
# | end of epoch   6 | time:  0.33s | valid loss 2.872689
# -----------------------------------------------------------------------------
# | epoch   7 |     1/    5 batches | lr 0.367546 | ms/batch 121.71 | loss 2.826569
# | epoch   7 |     2/    5 batches | lr 0.367546 | ms/batch 52.26 | loss 2.785625
# | epoch   7 |     3/    5 batches | lr 0.367546 | ms/batch 40.26 | loss 0.021401
# | epoch   7 |     4/    5 batches | lr 0.367546 | ms/batch 59.54 | loss 2.257009
# | epoch   7 |     5/    5 batches | lr 0.367546 | ms/batch 45.74 | loss 0.169075
# -----------------------------------------------------------------------------
# | end of epoch   7 | time:  0.34s | valid loss 0.155040
# -----------------------------------------------------------------------------
# | epoch   8 |     1/    5 batches | lr 0.349169 | ms/batch 116.27 | loss 1.167817
# | epoch   8 |     2/    5 batches | lr 0.349169 | ms/batch 45.49 | loss 1.006197
# | epoch   8 |     3/    5 batches | lr 0.349169 | ms/batch 48.06 | loss 0.171171
# | epoch   8 |     4/    5 batches | lr 0.349169 | ms/batch 41.47 | loss 0.926473
# | epoch   8 |     5/    5 batches | lr 0.349169 | ms/batch 47.09 | loss 0.151920
# -----------------------------------------------------------------------------
# | end of epoch   8 | time:  0.33s | valid loss 0.357131
# -----------------------------------------------------------------------------
# | epoch   9 |     1/    5 batches | lr 0.331710 | ms/batch 102.02 | loss 0.825427
# | epoch   9 |     2/    5 batches | lr 0.331710 | ms/batch 50.09 | loss 0.846150
# | epoch   9 |     3/    5 batches | lr 0.331710 | ms/batch 48.70 | loss 0.299513
# | epoch   9 |     4/    5 batches | lr 0.331710 | ms/batch 43.34 | loss 0.475958
# | epoch   9 |     5/    5 batches | lr 0.331710 | ms/batch 47.67 | loss 0.120080
# -----------------------------------------------------------------------------
# | end of epoch   9 | time:  0.31s | valid loss 0.844043
# -----------------------------------------------------------------------------
# | epoch  10 |     1/    5 batches | lr 0.315125 | ms/batch 104.69 | loss 0.936653
# | epoch  10 |     2/    5 batches | lr 0.315125 | ms/batch 51.39 | loss 0.353940
# | epoch  10 |     3/    5 batches | lr 0.315125 | ms/batch 47.93 | loss 0.341421
# | epoch  10 |     4/    5 batches | lr 0.315125 | ms/batch 47.79 | loss 0.193460
# | epoch  10 |     5/    5 batches | lr 0.315125 | ms/batch 42.55 | loss 0.418983
# -----------------------------------------------------------------------------
# | end of epoch  10 | time:  0.32s | valid loss 0.139082
# -----------------------------------------------------------------------------
# | epoch  11 |     1/    5 batches | lr 0.299368 | ms/batch 93.43 | loss 0.197818
# | epoch  11 |     2/    5 batches | lr 0.299368 | ms/batch 59.19 | loss 0.092845
# | epoch  11 |     3/    5 batches | lr 0.299368 | ms/batch 49.02 | loss 1.618512
# | epoch  11 |     4/    5 batches | lr 0.299368 | ms/batch 47.70 | loss 0.090630
# | epoch  11 |     5/    5 batches | lr 0.299368 | ms/batch 41.64 | loss 1.397409
# -----------------------------------------------------------------------------
# | end of epoch  11 | time:  0.31s | valid loss 0.040879
# -----------------------------------------------------------------------------
# | epoch  12 |     1/    5 batches | lr 0.284400 | ms/batch 101.14 | loss 1.297569
# | epoch  12 |     2/    5 batches | lr 0.284400 | ms/batch 49.76 | loss 0.059298
# | epoch  12 |     3/    5 batches | lr 0.284400 | ms/batch 52.60 | loss 1.145784
# | epoch  12 |     4/    5 batches | lr 0.284400 | ms/batch 44.68 | loss 0.039117
# | epoch  12 |     5/    5 batches | lr 0.284400 | ms/batch 40.06 | loss 0.815036
# -----------------------------------------------------------------------------
# | end of epoch  12 | time:  0.31s | valid loss 0.111025
# -----------------------------------------------------------------------------
# | epoch  13 |     1/    5 batches | lr 0.270180 | ms/batch 105.10 | loss 0.607272
# | epoch  13 |     2/    5 batches | lr 0.270180 | ms/batch 51.66 | loss 0.040255
# | epoch  13 |     3/    5 batches | lr 0.270180 | ms/batch 52.18 | loss 0.496035
# | epoch  13 |     4/    5 batches | lr 0.270180 | ms/batch 49.97 | loss 0.155636
# | epoch  13 |     5/    5 batches | lr 0.270180 | ms/batch 31.70 | loss 0.328561
# -----------------------------------------------------------------------------
# | end of epoch  13 | time:  0.32s | valid loss 0.124285
# -----------------------------------------------------------------------------
# | epoch  14 |     1/    5 batches | lr 0.256671 | ms/batch 116.69 | loss 0.395536
# | epoch  14 |     2/    5 batches | lr 0.256671 | ms/batch 53.13 | loss 0.046067
# | epoch  14 |     3/    5 batches | lr 0.256671 | ms/batch 45.11 | loss 0.288997
# | epoch  14 |     4/    5 batches | lr 0.256671 | ms/batch 48.61 | loss 0.057985
# | epoch  14 |     5/    5 batches | lr 0.256671 | ms/batch 47.42 | loss 0.524597
# -----------------------------------------------------------------------------
# | end of epoch  14 | time:  0.34s | valid loss 0.069926
# -----------------------------------------------------------------------------
# | epoch  15 |     1/    5 batches | lr 0.243837 | ms/batch 89.77 | loss 0.428942
# | epoch  15 |     2/    5 batches | lr 0.243837 | ms/batch 60.26 | loss 0.061348
# | epoch  15 |     3/    5 batches | lr 0.243837 | ms/batch 50.86 | loss 0.267749
# | epoch  15 |     4/    5 batches | lr 0.243837 | ms/batch 43.76 | loss 0.034582
# | epoch  15 |     5/    5 batches | lr 0.243837 | ms/batch 29.03 | loss 0.370701
# -----------------------------------------------------------------------------
# | end of epoch  15 | time:  0.31s | valid loss 0.014340
# -----------------------------------------------------------------------------
# | epoch  16 |     1/    5 batches | lr 0.231646 | ms/batch 96.78 | loss 0.378659
# | epoch  16 |     2/    5 batches | lr 0.231646 | ms/batch 36.31 | loss 0.040575
# | epoch  16 |     3/    5 batches | lr 0.231646 | ms/batch 55.54 | loss 0.275734
# | epoch  16 |     4/    5 batches | lr 0.231646 | ms/batch 39.16 | loss 0.027845
# | epoch  16 |     5/    5 batches | lr 0.231646 | ms/batch 38.99 | loss 0.245192
# -----------------------------------------------------------------------------
# | end of epoch  16 | time:  0.28s | valid loss 0.037818
# -----------------------------------------------------------------------------
# | epoch  17 |     1/    5 batches | lr 0.220063 | ms/batch 88.01 | loss 0.407579
# | epoch  17 |     2/    5 batches | lr 0.220063 | ms/batch 46.09 | loss 0.069837
# | epoch  17 |     3/    5 batches | lr 0.220063 | ms/batch 44.01 | loss 0.210893
# | epoch  17 |     4/    5 batches | lr 0.220063 | ms/batch 33.09 | loss 0.043613
# | epoch  17 |     5/    5 batches | lr 0.220063 | ms/batch 43.91 | loss 0.212321
# -----------------------------------------------------------------------------
# | end of epoch  17 | time:  0.27s | valid loss 0.066921
# -----------------------------------------------------------------------------
# | epoch  18 |     1/    5 batches | lr 0.209060 | ms/batch 81.33 | loss 0.194218
# | epoch  18 |     2/    5 batches | lr 0.209060 | ms/batch 40.02 | loss 0.070060
# | epoch  18 |     3/    5 batches | lr 0.209060 | ms/batch 39.33 | loss 0.116097
# | epoch  18 |     4/    5 batches | lr 0.209060 | ms/batch 39.37 | loss 0.041433
# | epoch  18 |     5/    5 batches | lr 0.209060 | ms/batch 24.85 | loss 0.174770
# -----------------------------------------------------------------------------
# | end of epoch  18 | time:  0.25s | valid loss 0.091820
# -----------------------------------------------------------------------------
# | epoch  19 |     1/    5 batches | lr 0.198607 | ms/batch 74.00 | loss 0.193300
# | epoch  19 |     2/    5 batches | lr 0.198607 | ms/batch 33.20 | loss 0.067416
# | epoch  19 |     3/    5 batches | lr 0.198607 | ms/batch 30.30 | loss 0.138901
# | epoch  19 |     4/    5 batches | lr 0.198607 | ms/batch 37.33 | loss 0.051864
# | epoch  19 |     5/    5 batches | lr 0.198607 | ms/batch 31.00 | loss 0.111082
# -----------------------------------------------------------------------------
# | end of epoch  19 | time:  0.22s | valid loss 0.074125
# -----------------------------------------------------------------------------
# | epoch  20 |     1/    5 batches | lr 0.188677 | ms/batch 68.64 | loss 0.260035
# | epoch  20 |     2/    5 batches | lr 0.188677 | ms/batch 33.05 | loss 0.071855
# | epoch  20 |     3/    5 batches | lr 0.188677 | ms/batch 27.51 | loss 0.086161
# | epoch  20 |     4/    5 batches | lr 0.188677 | ms/batch 33.21 | loss 0.052818
# | epoch  20 |     5/    5 batches | lr 0.188677 | ms/batch 29.29 | loss 0.120027
# -----------------------------------------------------------------------------
# | end of epoch  20 | time:  0.21s | valid loss 0.063770
# -----------------------------------------------------------------------------
# | epoch  21 |     1/    5 batches | lr 0.179243 | ms/batch 60.40 | loss 0.174581
# | epoch  21 |     2/    5 batches | lr 0.179243 | ms/batch 30.65 | loss 0.071368
# | epoch  21 |     3/    5 batches | lr 0.179243 | ms/batch 36.42 | loss 0.101600
# | epoch  21 |     4/    5 batches | lr 0.179243 | ms/batch 29.77 | loss 0.047013
# | epoch  21 |     5/    5 batches | lr 0.179243 | ms/batch 29.54 | loss 0.091702
# -----------------------------------------------------------------------------
# | end of epoch  21 | time:  0.20s | valid loss 0.091779
# -----------------------------------------------------------------------------
# | epoch  22 |     1/    5 batches | lr 0.170281 | ms/batch 53.80 | loss 0.124185
# | epoch  22 |     2/    5 batches | lr 0.170281 | ms/batch 35.45 | loss 0.083271
# | epoch  22 |     3/    5 batches | lr 0.170281 | ms/batch 24.73 | loss 0.075173
# | epoch  22 |     4/    5 batches | lr 0.170281 | ms/batch 33.38 | loss 0.060848
# | epoch  22 |     5/    5 batches | lr 0.170281 | ms/batch 26.65 | loss 0.060346
# -----------------------------------------------------------------------------
# | end of epoch  22 | time:  0.18s | valid loss 0.034030
# -----------------------------------------------------------------------------
# | epoch  23 |     1/    5 batches | lr 0.161767 | ms/batch 57.26 | loss 0.087719
# | epoch  23 |     2/    5 batches | lr 0.161767 | ms/batch 29.62 | loss 0.041964
# | epoch  23 |     3/    5 batches | lr 0.161767 | ms/batch 31.78 | loss 0.081419
# | epoch  23 |     4/    5 batches | lr 0.161767 | ms/batch 28.08 | loss 0.034154
# | epoch  23 |     5/    5 batches | lr 0.161767 | ms/batch 31.81 | loss 0.065822
# -----------------------------------------------------------------------------
# | end of epoch  23 | time:  0.19s | valid loss 0.021572
# -----------------------------------------------------------------------------
# | epoch  24 |     1/    5 batches | lr 0.153678 | ms/batch 59.28 | loss 0.147252
# | epoch  24 |     2/    5 batches | lr 0.153678 | ms/batch 27.80 | loss 0.046767
# | epoch  24 |     3/    5 batches | lr 0.153678 | ms/batch 29.51 | loss 0.037723
# | epoch  24 |     4/    5 batches | lr 0.153678 | ms/batch 27.81 | loss 0.038392
# | epoch  24 |     5/    5 batches | lr 0.153678 | ms/batch 35.81 | loss 0.036283
# -----------------------------------------------------------------------------
# | end of epoch  24 | time:  0.19s | valid loss 0.045374
# -----------------------------------------------------------------------------
# | epoch  25 |     1/    5 batches | lr 0.145995 | ms/batch 67.38 | loss 0.099655
# | epoch  25 |     2/    5 batches | lr 0.145995 | ms/batch 34.00 | loss 0.044464
# | epoch  25 |     3/    5 batches | lr 0.145995 | ms/batch 29.60 | loss 0.077785
# | epoch  25 |     4/    5 batches | lr 0.145995 | ms/batch 33.81 | loss 0.033427
# | epoch  25 |     5/    5 batches | lr 0.145995 | ms/batch 31.80 | loss 0.050217
# -----------------------------------------------------------------------------
# | end of epoch  25 | time:  0.21s | valid loss 0.008284
# -----------------------------------------------------------------------------
# | epoch  26 |     1/    5 batches | lr 0.138695 | ms/batch 62.82 | loss 0.068908
# | epoch  26 |     2/    5 batches | lr 0.138695 | ms/batch 33.52 | loss 0.046857
# | epoch  26 |     3/    5 batches | lr 0.138695 | ms/batch 32.66 | loss 0.065827
# | epoch  26 |     4/    5 batches | lr 0.138695 | ms/batch 33.25 | loss 0.036981
# | epoch  26 |     5/    5 batches | lr 0.138695 | ms/batch 30.66 | loss 0.065464
# -----------------------------------------------------------------------------
# | end of epoch  26 | time:  0.21s | valid loss 0.012892
# -----------------------------------------------------------------------------
# | epoch  27 |     1/    5 batches | lr 0.131760 | ms/batch 69.78 | loss 0.085104
# | epoch  27 |     2/    5 batches | lr 0.131760 | ms/batch 27.74 | loss 0.030090
# | epoch  27 |     3/    5 batches | lr 0.131760 | ms/batch 34.15 | loss 0.040355
# | epoch  27 |     4/    5 batches | lr 0.131760 | ms/batch 29.35 | loss 0.021011
# | epoch  27 |     5/    5 batches | lr 0.131760 | ms/batch 35.48 | loss 0.030650
# -----------------------------------------------------------------------------
# | end of epoch  27 | time:  0.21s | valid loss 0.025780
# -----------------------------------------------------------------------------
# | epoch  28 |     1/    5 batches | lr 0.125172 | ms/batch 64.84 | loss 0.062481
# | epoch  28 |     2/    5 batches | lr 0.125172 | ms/batch 29.65 | loss 0.030928
# | epoch  28 |     3/    5 batches | lr 0.125172 | ms/batch 32.21 | loss 0.045608
# | epoch  28 |     4/    5 batches | lr 0.125172 | ms/batch 32.26 | loss 0.017285
# | epoch  28 |     5/    5 batches | lr 0.125172 | ms/batch 23.98 | loss 0.037762
# -----------------------------------------------------------------------------
# | end of epoch  28 | time:  0.19s | valid loss 0.027420
# -----------------------------------------------------------------------------
# | epoch  29 |     1/    5 batches | lr 0.118913 | ms/batch 64.64 | loss 0.069830
# | epoch  29 |     2/    5 batches | lr 0.118913 | ms/batch 36.50 | loss 0.027983
# | epoch  29 |     3/    5 batches | lr 0.118913 | ms/batch 27.08 | loss 0.046300
# | epoch  29 |     4/    5 batches | lr 0.118913 | ms/batch 33.29 | loss 0.024482
# | epoch  29 |     5/    5 batches | lr 0.118913 | ms/batch 28.79 | loss 0.043954
# -----------------------------------------------------------------------------
# | end of epoch  29 | time:  0.20s | valid loss 0.046416
# -----------------------------------------------------------------------------
# | epoch  30 |     1/    5 batches | lr 0.112968 | ms/batch 58.06 | loss 0.053141
# | epoch  30 |     2/    5 batches | lr 0.112968 | ms/batch 31.52 | loss 0.027160
# | epoch  30 |     3/    5 batches | lr 0.112968 | ms/batch 32.55 | loss 0.026725
# | epoch  30 |     4/    5 batches | lr 0.112968 | ms/batch 28.15 | loss 0.019304
# | epoch  30 |     5/    5 batches | lr 0.112968 | ms/batch 34.75 | loss 0.023591
# -----------------------------------------------------------------------------
# | end of epoch  30 | time:  0.20s | valid loss 0.008765
# -----------------------------------------------------------------------------
# | epoch  31 |     1/    5 batches | lr 0.107319 | ms/batch 60.36 | loss 0.046696
# | epoch  31 |     2/    5 batches | lr 0.107319 | ms/batch 31.24 | loss 0.025729
# | epoch  31 |     3/    5 batches | lr 0.107319 | ms/batch 35.93 | loss 0.027504
# | epoch  31 |     4/    5 batches | lr 0.107319 | ms/batch 26.60 | loss 0.018023
# | epoch  31 |     5/    5 batches | lr 0.107319 | ms/batch 27.57 | loss 0.027904
# -----------------------------------------------------------------------------
# | end of epoch  31 | time:  0.19s | valid loss 0.012704
# -----------------------------------------------------------------------------
# | epoch  32 |     1/    5 batches | lr 0.101953 | ms/batch 62.50 | loss 0.054176
# | epoch  32 |     2/    5 batches | lr 0.101953 | ms/batch 27.05 | loss 0.023440
# | epoch  32 |     3/    5 batches | lr 0.101953 | ms/batch 28.69 | loss 0.025490
# | epoch  32 |     4/    5 batches | lr 0.101953 | ms/batch 27.64 | loss 0.015809
# | epoch  32 |     5/    5 batches | lr 0.101953 | ms/batch 33.99 | loss 0.021339
# -----------------------------------------------------------------------------
# | end of epoch  32 | time:  0.19s | valid loss 0.022936
# -----------------------------------------------------------------------------
# | epoch  33 |     1/    5 batches | lr 0.096856 | ms/batch 61.34 | loss 0.041027
# | epoch  33 |     2/    5 batches | lr 0.096856 | ms/batch 28.51 | loss 0.013316
# | epoch  33 |     3/    5 batches | lr 0.096856 | ms/batch 24.61 | loss 0.010274
# | epoch  33 |     4/    5 batches | lr 0.096856 | ms/batch 31.66 | loss 0.012787
# | epoch  33 |     5/    5 batches | lr 0.096856 | ms/batch 27.12 | loss 0.031653
# -----------------------------------------------------------------------------
# | end of epoch  33 | time:  0.18s | valid loss 0.015898
# -----------------------------------------------------------------------------
# | epoch  34 |     1/    5 batches | lr 0.092013 | ms/batch 62.45 | loss 0.034324
# | epoch  34 |     2/    5 batches | lr 0.092013 | ms/batch 27.80 | loss 0.015500
# | epoch  34 |     3/    5 batches | lr 0.092013 | ms/batch 27.93 | loss 0.027125
# | epoch  34 |     4/    5 batches | lr 0.092013 | ms/batch 27.58 | loss 0.014100
# | epoch  34 |     5/    5 batches | lr 0.092013 | ms/batch 27.85 | loss 0.016155
# -----------------------------------------------------------------------------
# | end of epoch  34 | time:  0.18s | valid loss 0.010605
# -----------------------------------------------------------------------------
# | epoch  35 |     1/    5 batches | lr 0.087412 | ms/batch 62.74 | loss 0.040002
# | epoch  35 |     2/    5 batches | lr 0.087412 | ms/batch 30.90 | loss 0.022509
# | epoch  35 |     3/    5 batches | lr 0.087412 | ms/batch 29.49 | loss 0.016601
# | epoch  35 |     4/    5 batches | lr 0.087412 | ms/batch 32.94 | loss 0.014386
# | epoch  35 |     5/    5 batches | lr 0.087412 | ms/batch 24.59 | loss 0.015152
# -----------------------------------------------------------------------------
# | end of epoch  35 | time:  0.19s | valid loss 0.009795
# -----------------------------------------------------------------------------
# | epoch  36 |     1/    5 batches | lr 0.083042 | ms/batch 62.45 | loss 0.045426
# | epoch  36 |     2/    5 batches | lr 0.083042 | ms/batch 34.72 | loss 0.016564
# | epoch  36 |     3/    5 batches | lr 0.083042 | ms/batch 27.78 | loss 0.010046
# | epoch  36 |     4/    5 batches | lr 0.083042 | ms/batch 30.39 | loss 0.003141
# | epoch  36 |     5/    5 batches | lr 0.083042 | ms/batch 25.17 | loss 0.004218
# -----------------------------------------------------------------------------
# | end of epoch  36 | time:  0.19s | valid loss 0.017120
# -----------------------------------------------------------------------------
# | epoch  37 |     1/    5 batches | lr 0.078890 | ms/batch 55.59 | loss 0.015184
# | epoch  37 |     2/    5 batches | lr 0.078890 | ms/batch 33.94 | loss 0.006344
# | epoch  37 |     3/    5 batches | lr 0.078890 | ms/batch 21.81 | loss 0.006537
# | epoch  37 |     4/    5 batches | lr 0.078890 | ms/batch 37.00 | loss 0.004880
# | epoch  37 |     5/    5 batches | lr 0.078890 | ms/batch 26.20 | loss 0.006122
# -----------------------------------------------------------------------------
# | end of epoch  37 | time:  0.19s | valid loss 0.019778
# -----------------------------------------------------------------------------
# | epoch  38 |     1/    5 batches | lr 0.074945 | ms/batch 55.50 | loss 0.018458
# | epoch  38 |     2/    5 batches | lr 0.074945 | ms/batch 29.77 | loss 0.006333
# | epoch  38 |     3/    5 batches | lr 0.074945 | ms/batch 32.00 | loss 0.007479
# | epoch  38 |     4/    5 batches | lr 0.074945 | ms/batch 46.40 | loss 0.005658
# | epoch  38 |     5/    5 batches | lr 0.074945 | ms/batch 43.81 | loss 0.005909
# -----------------------------------------------------------------------------
# | end of epoch  38 | time:  0.22s | valid loss 0.016306
# -----------------------------------------------------------------------------
# | epoch  39 |     1/    5 batches | lr 0.071198 | ms/batch 64.39 | loss 0.016537
# | epoch  39 |     2/    5 batches | lr 0.071198 | ms/batch 27.79 | loss 0.005594
# | epoch  39 |     3/    5 batches | lr 0.071198 | ms/batch 27.49 | loss 0.006257
# | epoch  39 |     4/    5 batches | lr 0.071198 | ms/batch 28.16 | loss 0.003932
# | epoch  39 |     5/    5 batches | lr 0.071198 | ms/batch 34.57 | loss 0.004804
# -----------------------------------------------------------------------------
# | end of epoch  39 | time:  0.19s | valid loss 0.014470
# -----------------------------------------------------------------------------
# | epoch  40 |     1/    5 batches | lr 0.067638 | ms/batch 63.85 | loss 0.014993
# | epoch  40 |     2/    5 batches | lr 0.067638 | ms/batch 33.39 | loss 0.005330
# | epoch  40 |     3/    5 batches | lr 0.067638 | ms/batch 34.11 | loss 0.005792
# | epoch  40 |     4/    5 batches | lr 0.067638 | ms/batch 26.96 | loss 0.003235
# | epoch  40 |     5/    5 batches | lr 0.067638 | ms/batch 27.96 | loss 0.004588
# -----------------------------------------------------------------------------
# | end of epoch  40 | time:  0.19s | valid loss 0.013787
# -----------------------------------------------------------------------------
# | epoch  41 |     1/    5 batches | lr 0.064256 | ms/batch 57.86 | loss 0.014532
# | epoch  41 |     2/    5 batches | lr 0.064256 | ms/batch 33.48 | loss 0.005231
# | epoch  41 |     3/    5 batches | lr 0.064256 | ms/batch 27.64 | loss 0.005674
# | epoch  41 |     4/    5 batches | lr 0.064256 | ms/batch 33.82 | loss 0.002929
# | epoch  41 |     5/    5 batches | lr 0.064256 | ms/batch 31.06 | loss 0.004575
# -----------------------------------------------------------------------------
# | end of epoch  41 | time:  0.20s | valid loss 0.013252
# -----------------------------------------------------------------------------
# | epoch  42 |     1/    5 batches | lr 0.061043 | ms/batch 55.63 | loss 0.014214
# | epoch  42 |     2/    5 batches | lr 0.061043 | ms/batch 27.79 | loss 0.005192
# | epoch  42 |     3/    5 batches | lr 0.061043 | ms/batch 31.10 | loss 0.005615
# | epoch  42 |     4/    5 batches | lr 0.061043 | ms/batch 30.59 | loss 0.002720
# | epoch  42 |     5/    5 batches | lr 0.061043 | ms/batch 28.64 | loss 0.004594
# -----------------------------------------------------------------------------
# | end of epoch  42 | time:  0.18s | valid loss 0.012749
# -----------------------------------------------------------------------------
# | epoch  43 |     1/    5 batches | lr 0.057991 | ms/batch 62.45 | loss 0.013933
# | epoch  43 |     2/    5 batches | lr 0.057991 | ms/batch 27.88 | loss 0.005182
# | epoch  43 |     3/    5 batches | lr 0.057991 | ms/batch 27.71 | loss 0.005556
# | epoch  43 |     4/    5 batches | lr 0.057991 | ms/batch 33.07 | loss 0.002558
# | epoch  43 |     5/    5 batches | lr 0.057991 | ms/batch 29.56 | loss 0.004612
# -----------------------------------------------------------------------------
# | end of epoch  43 | time:  0.19s | valid loss 0.012269
# -----------------------------------------------------------------------------
# | epoch  44 |     1/    5 batches | lr 0.055092 | ms/batch 62.52 | loss 0.013679
# | epoch  44 |     2/    5 batches | lr 0.055092 | ms/batch 30.88 | loss 0.005186
# | epoch  44 |     3/    5 batches | lr 0.055092 | ms/batch 31.54 | loss 0.005491
# | epoch  44 |     4/    5 batches | lr 0.055092 | ms/batch 27.84 | loss 0.002427
# | epoch  44 |     5/    5 batches | lr 0.055092 | ms/batch 31.61 | loss 0.004620
# -----------------------------------------------------------------------------
# | end of epoch  44 | time:  0.19s | valid loss 0.011815
# -----------------------------------------------------------------------------
# | epoch  45 |     1/    5 batches | lr 0.052337 | ms/batch 55.04 | loss 0.013453
# | epoch  45 |     2/    5 batches | lr 0.052337 | ms/batch 27.81 | loss 0.005192
# | epoch  45 |     3/    5 batches | lr 0.052337 | ms/batch 30.14 | loss 0.005421
# | epoch  45 |     4/    5 batches | lr 0.052337 | ms/batch 32.39 | loss 0.002320
# | epoch  45 |     5/    5 batches | lr 0.052337 | ms/batch 27.63 | loss 0.004616
# -----------------------------------------------------------------------------
# | end of epoch  45 | time:  0.18s | valid loss 0.011388
# -----------------------------------------------------------------------------
# | epoch  46 |     1/    5 batches | lr 0.049720 | ms/batch 55.22 | loss 0.013254
# | epoch  46 |     2/    5 batches | lr 0.049720 | ms/batch 31.95 | loss 0.005197
# | epoch  46 |     3/    5 batches | lr 0.049720 | ms/batch 30.44 | loss 0.005347
# | epoch  46 |     4/    5 batches | lr 0.049720 | ms/batch 29.70 | loss 0.002230
# | epoch  46 |     5/    5 batches | lr 0.049720 | ms/batch 25.60 | loss 0.004602
# -----------------------------------------------------------------------------
# | end of epoch  46 | time:  0.18s | valid loss 0.010990
# -----------------------------------------------------------------------------
# | epoch  47 |     1/    5 batches | lr 0.047234 | ms/batch 90.38 | loss 0.013082
# | epoch  47 |     2/    5 batches | lr 0.047234 | ms/batch 41.76 | loss 0.005199
# | epoch  47 |     3/    5 batches | lr 0.047234 | ms/batch 27.44 | loss 0.005274
# | epoch  47 |     4/    5 batches | lr 0.047234 | ms/batch 27.42 | loss 0.002154
# | epoch  47 |     5/    5 batches | lr 0.047234 | ms/batch 27.81 | loss 0.004577
# -----------------------------------------------------------------------------
# | end of epoch  47 | time:  0.22s | valid loss 0.010621
# -----------------------------------------------------------------------------
# | epoch  48 |     1/    5 batches | lr 0.044872 | ms/batch 55.53 | loss 0.012934
# | epoch  48 |     2/    5 batches | lr 0.044872 | ms/batch 24.90 | loss 0.005197
# | epoch  48 |     3/    5 batches | lr 0.044872 | ms/batch 32.17 | loss 0.005204
# | epoch  48 |     4/    5 batches | lr 0.044872 | ms/batch 27.03 | loss 0.002091
# | epoch  48 |     5/    5 batches | lr 0.044872 | ms/batch 26.93 | loss 0.004545
# -----------------------------------------------------------------------------
# | end of epoch  48 | time:  0.17s | valid loss 0.010281
# -----------------------------------------------------------------------------
# | epoch  49 |     1/    5 batches | lr 0.042629 | ms/batch 58.01 | loss 0.012809
# | epoch  49 |     2/    5 batches | lr 0.042629 | ms/batch 25.34 | loss 0.005192
# | epoch  49 |     3/    5 batches | lr 0.042629 | ms/batch 27.69 | loss 0.005139
# | epoch  49 |     4/    5 batches | lr 0.042629 | ms/batch 28.29 | loss 0.002039
# | epoch  49 |     5/    5 batches | lr 0.042629 | ms/batch 33.66 | loss 0.004504
# -----------------------------------------------------------------------------
# | end of epoch  49 | time:  0.18s | valid loss 0.009969
# -----------------------------------------------------------------------------
# | epoch  50 |     1/    5 batches | lr 0.040497 | ms/batch 49.28 | loss 0.012701
# | epoch  50 |     2/    5 batches | lr 0.040497 | ms/batch 28.26 | loss 0.005184
# | epoch  50 |     3/    5 batches | lr 0.040497 | ms/batch 27.31 | loss 0.005078
# | epoch  50 |     4/    5 batches | lr 0.040497 | ms/batch 27.69 | loss 0.001996
# | epoch  50 |     5/    5 batches | lr 0.040497 | ms/batch 29.96 | loss 0.004458
# -----------------------------------------------------------------------------
# | end of epoch  50 | time:  0.18s | valid loss 0.009686
# -----------------------------------------------------------------------------

# %%
# plot loss functions
epochs_list = np.arange(1,epochs + 1)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
ax.set_title("Loss vs. Epochs")
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
ax.plot(epochs_list, train_loss, label='Training Loss')
if val is not None:
    ax.plot(epochs_list, valid_loss, label='Validation Loss')
ax.legend() 
plt.show()
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.

# %%
# calculate test loss
test_loss = evaluate(best_model, test_data, bptt_src, bptt_tgt, overlap, criterion, predicted_feature)
test_ppl = math.exp(test_loss)
print('-' * 77)
print(f'test loss {test_loss:5.6f}')
print('-' * 77)
# Out:
# -----------------------------------------------------------------------------
# test loss 0.008770
# -----------------------------------------------------------------------------

# %%
def greedy_decode(model, src, bptt_src, pred_len, overlap):
    """use the model to create a pridection of pred_len out of src
    
    Args:
        model: nn.Module, the model you want to run the data in
        src: Tensor, shape [N, 1, E]
        bptt_src: int, size of back propagation through time, sequence length of source
        pred_len: int, desired prediction length
        overlap: int, number of overlapping elements between source and target
        
    Returns:
        greedy_output: tesnor, shape [pred_len, 1, E], holds the predictions based on src

    """
    model.eval()
    if overlap == 0:
        start_point = src[-1:, :, :]
        src = src[:-1, :, :]
    else:
        start_point = src[-overlap:,:,:]
    bptt_src = src.size(0)
    src_mask = torch.zeros((bptt_src,bptt_src), dtype=torch.bool).to(device)
    memory = model.encode(src, src_mask)
    targets = start_point
    for i in range(pred_len):
        tgt_mask = model.transformer.generate_square_subsequent_mask(targets.size(0)).to(device)
        prediction = model.decode(targets, memory, tgt_mask)
        prediction = model.generator(prediction)
        targets = torch.cat([start_point, prediction[:i+1]], dim=0)
        
    greedy_output = prediction[:pred_len,:,:]
    greedy_output = greedy_output.detach()
    return greedy_output

# %%
def estimate_BTC(best_model, test, num_features, bptt_src, bptt_tgt, overlap, predicted_feature, scaler, use_real=True, early_stop=1):
    """use the best model to create a pridection on the test up to early_stop percentage of it
    
    Args:
        model: nn.Module, the model you want to run the data in
        test: Tensor, shape [N, E]
        num_features: int, number of features used to train the model
        bptt_src: int, size of back propagation through time, sequence length of source
        bptt_tgt: int, size of back propagation through time, sequence length of target
        overlap: int, number of overlapping elements between source and target
        predicted_feature: int, index of the feature you want to evaluate in [0,E-1]
        scaler: function, scaler fitted to train set
        use_real: bool, when True use the real data for future predictions, when False use the previous prediction
        early_stop: float, percentage of test you want to predict (0,1]
        

    Returns:
        feature_unnormalized: ndarray, holds the real values of the chosen feature in the test in original scale
        feature_prediction_unnormalized: ndarray, holds the predicted values of the chosen feature starting from bptt_src in original scale
        inference_bptt_src: int, starting point of the predictions
    """
    inference_batch_size = 1
    inference_bptt_src = bptt_src + (overlap == 0)
    pred_len = min(bptt_tgt - overlap, bptt_tgt - 1)
    test_data = betchify(test[:, :num_features], inference_batch_size).float()
    num_iter = (test_data.size(0) - bptt_src) // pred_len
    inference_data = test_data[:inference_bptt_src, :, :]
    for i in range(num_iter):
        prediction = greedy_decode(best_model, inference_data, bptt_src, pred_len, overlap)
        if use_real:
            inference_data = test_data[i * pred_len: i * pred_len + inference_bptt_src, :, :]
        else:
            inference_data =  torch.cat([inference_data, prediction], dim=0)[pred_len:]
        if i == 0:
            predictions = prediction
        else:
            predictions = torch.cat([predictions, prediction], dim=0)
        if i > num_iter * early_stop:
            break
            
    feature_unnormalized = scaler.inverse_transform(torch.transpose(test_data, 0, 1).reshape(-1,num_features).cpu())[:,predicted_feature]
    feature_prediction_unnormalized = scaler.inverse_transform(torch.transpose(predictions, 0, 1).reshape(-1,num_features).cpu())[:,predicted_feature]
    
    return feature_unnormalized, feature_prediction_unnormalized, inference_bptt_src

# %%
# predict over the test set
early_stop = 1
feature_real, feature_prediction, pred_start = estimate_BTC(best_model, test, num_features, bptt_src, bptt_tgt,
                                                            overlap, predicted_feature, scaler, use_real=True, early_stop=early_stop)
real_time = np.arange(0, np.size(feature_real))
prediction_time = np.arange(pred_start, pred_start + np.size(feature_prediction))

# %%
# plot predictions with real price
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(1, 1 ,1)
ax.set_xlabel("Time [Minutes]")     
ax.set_ylabel("log_return [USD]")  
ax.set_title("log_return through time")   
ax.grid()
ax.plot(real_time, feature_real, label='Real Values')
ax.plot(prediction_time, feature_prediction, label='Predicted Values')
ax.set_xlim(0, np.size(prediction_time))
ax.set_ylim(min(min(feature_prediction), min(feature_real[:np.size(prediction_time)])), 
            max(max(feature_prediction), max(feature_real[:np.size(prediction_time)])))
ax.legend()    
plt.show()
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.

# %%
# plot predictions with real price - zoom in to point of interest
desired_range = [42550, 42650]
low = desired_range[0]
high = desired_range[1]
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(1, 1 ,1)
ax.set_xlabel("Time [Minutes]")     
ax.set_ylabel("Closing Price [USD]")  
ax.set_title("Closing price through time - Zoom In")   
ax.grid()
ax.plot(real_time, feature_real, label='Real Values')
ax.plot(prediction_time, feature_prediction, label='Predicted Values')
ax.set_xlim(low, high)
ax.set_ylim(min(min(feature_prediction[low:high]), min(feature_real[low:high])), 
            max(max(feature_prediction[low:high]), max(feature_real[low:high])))
ax.legend()
plt.show()
